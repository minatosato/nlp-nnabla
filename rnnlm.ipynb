# %%
run rnnlm.py
# Out:
# 2017-12-30 10:10:20,983 [nnabla][INFO]: Initializing CPU extension...
# 2017-12-30 10:10:21,185 [nnabla][INFO]: Initializing CUDA extension...
# 2017-12-30 10:10:21,188 [nnabla][INFO]: Initializing cuDNN extension...
# Using TensorFlow backend.
# 2017-12-30 10:10:24,789 [nnabla][INFO]: DataSource with shuffle(True)
# 2017-12-30 10:10:24,795 [nnabla][INFO]: Using DataSourceWithMemoryCache
# 2017-12-30 10:10:24,796 [nnabla][INFO]: DataSource with shuffle(True)
# 2017-12-30 10:10:24,797 [nnabla][INFO]: On-memory
# 2017-12-30 10:10:24,798 [nnabla][INFO]: Using DataIterator
# 2017-12-30 10:10:24,807 [nnabla][INFO]: DataSource with shuffle(True)
# 2017-12-30 10:10:24,810 [nnabla][INFO]: Using DataSourceWithMemoryCache
# 2017-12-30 10:10:24,811 [nnabla][INFO]: DataSource with shuffle(True)
# 2017-12-30 10:10:24,812 [nnabla][INFO]: On-memory
# 2017-12-30 10:10:24,813 [nnabla][INFO]: Using DataIterator
# 100%|██████████| 164/164 [00:19<00:00,  8.61it/s]
# ...
