# %%
run char-cnn-lstmlm.py
# Out:
# 2018-01-05 10:13:14,583 [nnabla][INFO]: Initializing CPU extension...
# 2018-01-05 10:13:14,775 [nnabla][INFO]: Initializing CUDA extension...
# 2018-01-05 10:13:14,777 [nnabla][INFO]: Initializing cuDNN extension...
# Using TensorFlow backend.
# 2018-01-05 10:13:21,449 [nnabla][INFO]: DataSource with shuffle(True)
# 2018-01-05 10:13:21,455 [nnabla][INFO]: Using DataSourceWithMemoryCache
# 2018-01-05 10:13:21,456 [nnabla][INFO]: DataSource with shuffle(True)
# 2018-01-05 10:13:21,458 [nnabla][INFO]: On-memory
# 2018-01-05 10:13:21,459 [nnabla][INFO]: Using DataIterator
# 2018-01-05 10:13:21,469 [nnabla][INFO]: DataSource with shuffle(True)
# 2018-01-05 10:13:21,470 [nnabla][INFO]: Using DataSourceWithMemoryCache
# 2018-01-05 10:13:21,471 [nnabla][INFO]: DataSource with shuffle(True)
# 2018-01-05 10:13:21,471 [nnabla][INFO]: On-memory
# 2018-01-05 10:13:21,472 [nnabla][INFO]: Using DataIterator
# 100%|██████████| 164/164 [00:47<00:00,  3.44it/s]
# ...
