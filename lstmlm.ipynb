# %%
run lstmlm.py
# Out:
# 2017-12-30 10:24:57,670 [nnabla][INFO]: Initializing CPU extension...
# 2017-12-30 10:24:57,853 [nnabla][INFO]: Initializing CUDA extension...
# 2017-12-30 10:24:57,855 [nnabla][INFO]: Initializing cuDNN extension...
# Using TensorFlow backend.
# 2017-12-30 10:25:00,795 [nnabla][INFO]: DataSource with shuffle(True)
# 2017-12-30 10:25:00,801 [nnabla][INFO]: Using DataSourceWithMemoryCache
# 2017-12-30 10:25:00,801 [nnabla][INFO]: DataSource with shuffle(True)
# 2017-12-30 10:25:00,802 [nnabla][INFO]: On-memory
# 2017-12-30 10:25:00,803 [nnabla][INFO]: Using DataIterator
# 2017-12-30 10:25:00,810 [nnabla][INFO]: DataSource with shuffle(True)
# 2017-12-30 10:25:00,811 [nnabla][INFO]: Using DataSourceWithMemoryCache
# 2017-12-30 10:25:00,812 [nnabla][INFO]: DataSource with shuffle(True)
# 2017-12-30 10:25:00,813 [nnabla][INFO]: On-memory
# 2017-12-30 10:25:00,813 [nnabla][INFO]: Using DataIterator
# 100%|██████████| 164/164 [00:22<00:00,  7.23it/s]
# ...
