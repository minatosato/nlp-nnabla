# %%
run lstmlm.py
# Out:
# 2017-12-30 16:03:06,684 [nnabla][INFO]: DataSource with shuffle(True)
# 2017-12-30 16:03:06,691 [nnabla][INFO]: Using DataSourceWithMemoryCache
# 2017-12-30 16:03:06,692 [nnabla][INFO]: DataSource with shuffle(True)
# 2017-12-30 16:03:06,694 [nnabla][INFO]: On-memory
# 2017-12-30 16:03:06,695 [nnabla][INFO]: Using DataIterator
# 2017-12-30 16:03:06,697 [nnabla][INFO]: DataSource with shuffle(True)
# 2017-12-30 16:03:06,705 [nnabla][INFO]: Using DataSourceWithMemoryCache
# 2017-12-30 16:03:06,706 [nnabla][INFO]: DataSource with shuffle(True)
# 2017-12-30 16:03:06,708 [nnabla][INFO]: On-memory
# 2017-12-30 16:03:06,709 [nnabla][INFO]: Using DataIterator
# 100%|██████████| 164/164 [00:20<00:00,  7.91it/s]
# 2017-12-30 16:03:27,830 [nnabla][INFO]: iter=1 {perplexity}=1157.0102534253908
# 2017-12-30 16:03:27,831 [nnabla][INFO]: iter=1 {perplexity_valid}=974.6808839059328
# 100%|██████████| 164/164 [00:20<00:00,  7.93it/s]
# ...
